# %% [markdown]
# ### Spam Or Ham Classification

# %% [markdown]
# Build a classification model for the default of youTube spam or ham dataset. More info here:
# https://archive.ics.uci.edu/ml/datasets/YouTube+Spam+Collection
#
# - Study the ROC Curve & accuracy Score

# %%
import numpy as np
import pandas as pd

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# %% [markdown]
# ## Explore the data

# %%
path = r"C:\Users\Nafiseh\ML_projects\YouTube-Spam-Collection-v1"
files_name = ['\\Youtube01-Psy.csv' , '\\Youtube02-KatyPerry.csv' ,
              '\\Youtube03-LMFAO.csv', '\\Youtube04-Eminem.csv', '\\Youtube05-Shakira.csv']
dfs = []
for file in files_name:
    df = pd.read_csv(path + file , header = 0)
    dfs.append(df)

# %%
# union all the datasets:

df = pd.concat(dfs)

# %%
len(df)
# Out:
# 1956

# %%
df.head()
# Out:
#                                     COMMENT_ID            AUTHOR  \
# 0  LZQPQhLyRh80UYxNuaDWhIGQYNQ96IuCg-AYWqNPjpU         Julius NM
# 1  LZQPQhLyRh_C2cTtd9MvFRJedxydaVW-2sNg5Diuo4A       adam riyati
# 2  LZQPQhLyRh9MSZYnf8djyk0gEF9BHDPYrrK-qCczIY8  Evgeny Murashkin
# 3          z13jhp0bxqncu512g22wvzkasxmvvzjaz04   ElNino Melendez
# 4          z13fwbwp1oujthgqj04chlngpvzmtt3r3dw            GsMega
#
#                   DATE                                            CONTENT  \
# 0  2013-11-07T06:20:48  Huh, anyway check out this you[tube] channel: ...
# 1  2013-11-07T12:37:15  Hey guys check out my new channel and our firs...
# 2  2013-11-08T17:34:21             just for test I have to say murdev.com
# 3  2013-11-09T08:28:43   me shaking my sexy ass on my channel enjoy ^_^ ﻿
# 4  2013-11-10T16:05:38            watch?v=vtaRGgvGtWQ   Check this out .﻿
#
#    CLASS
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1956 entries, 0 to 369
# Data columns (total 5 columns):
# COMMENT_ID    1956 non-null object
# AUTHOR        1956 non-null object
# DATE          1711 non-null object
# CONTENT       1956 non-null object
# CLASS         1956 non-null int64
# dtypes: int64(1), object(4)
# memory usage: 91.7+ KB

# %% [markdown]
# <pre>
# For comments classification we need just need content and class columns.</pre>

# %%
# new dataframe with relative cloumns
df = df[["CONTENT", "CLASS"]]

# %%
df.shape
# Out:
# (1956, 2)

# %%
df["CLASS"].value_counts()
# Out:
# 1    1005
# 0     951
# Name: CLASS, dtype: int64

# %% [markdown]
# ## Prepare the data for ML algorithms

# %%
import re
import nltk
#nltk.download()

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# %%
stop_words = set(stopwords.words("english"))
ps = PorterStemmer()

# %%
corpus = []
for i in range(len(df)):
    comment = re.sub(r'[^a-zA-Z0-9]', ' ',df.iloc[i,0])
    comment = comment.lower()
    #comment = comment.split() #list of words
    comment =word_tokenize(comment)

    comment = [ps.stem(w) for w in comment if not w in stop_words]
    comment = ' '.join(comment)
    corpus.append(comment)

corpus
# Out:
# ['huh anyway check tube channel kobyoshi02',
#  'hey guy check new channel first vid us monkey monkey white shirt pleas leav like comment pleas subscrib',
#  'test say murdev com',
#  'shake sexi ass channel enjoy',
#  'watch v vtarggvgtwq check',
#  'hey check new websit site kid stuff kidsmediausa com',
#  'subscrib channel',
#  'turn mute soon came want check view',
#  'check channel funni video',
#  'u check channel tell next',
#  'hey subscrib',
#  'start read stop subscrib within one day entir famili die want stay aliv subscrib right',
#  'http twitter com gbphotographygb',
#  'subscrib like comment',
#  'pleas like http premium easypromosapp com votem 19924 616375350',
#  'hello like game art video scientif experi tutori lyric video much much pleas check channel subscrib start soon hope abl cover expect also check got far',
#  'check view',
#  'http www ebay com itm 171183229277 sspagenam strk meselx amp trksid p3984 m1555 l2649',
#  'http ubuntuon com 40beuutvu2zkxk4utgpz8k',
#  'edm apparel compani dedic bring music inspir design cloth perfect rave music festiv neon crop top tank top shirt v neck accessori follow us facebook instagraml free giveaway news visit site oncueapparel',
#  'think 100 million view come peopl want check view',
#  'subscrib channel peopl',
#  'show auburn pride http www teespr com tigermeathoodi',
#  'check view',
#  'check channel',
#  'marketglori com strategygam andrijamatf earn real money game',
#  'hey guy im 12 yr old music produc make chiptun 8bit music would wonder check 8bit remix even gangnamstyl 8bit remix would like check thank',
#  'check kyle rap yeah',
#  'dont even watch anymor come check 2 billion',
#  'subscrib free android game app',
#  'everyon pleas come check newest song memori martin luther king jr',
#  'came check view goodby',
#  'sub channel reason',
#  'check dubstep song firebal made fruiti loop realli took time watch v teloa6rio8o',
#  '2 billion come soon',
#  'dafuq korean song big usa mean support korean last time check want bomb us',
#  'check channel pleas listen best music ever p',
#  'sub 4 sub pleas like comment want succesful youtub ppleas like comment subscrib take 10 second pleas subscrib ill subscrib back thank',
#  'hey everyon start first yt channel would grate peopl could check first clip bf4 give advic video could improv also sure go check see im thank time hater hate win',
#  'project effect music foto web site anoth find buy http audiojungl net user eugenekalinin portfolio ref eugenekalinin',
#  'youtub codytolleson awesom video subscrib back',
#  'like roblox minecraft world warcraft gta5 mario suscrib channel',
#  'subscrib subscrib must like czfcxsn0jnq',
#  'http www twitch tv jaroadc come follow watch stream',
#  'like raw talent raw lyric straight real hip hop everyon check newest sound dizzi x got juic prod drug model citizen comment tell think dont lazi 1 7 prophetz',
#  'subscrib channel',
#  '1 884 034 783 view pl comment view count next hour p',
#  'http www avaaz org po petit youtub corpor fox broadcast compani anular os strike canal nostalgia cxpzpgb',
#  'go check view 3',
#  'thumb u check video see hw view got',
#  'plz subscrib channel subscrib back xx',
#  'check back often help reach 2x10 9 view avoid watch babi',
#  'video get 2 billion peopl check hit 2 billion yet',
#  'http www facebook com page brew crew 2014 134470083389909 like facebook page chanc win iphon 5s',
#  'get gwar play 2015 superbowl http www chang org petit nation footbal leagu allow gwar perform 2015 super bowl halftim show share',
#  'pl follow channel http www twitch tv sevadu',
#  'hi guy check youtub channel',
#  'subscrib like video minecraft',
#  'http tankionlin com friend cd92db3f4 great game check',
#  'subscrib',
#  'im check much view',
#  'first comment chuck norru ovbious',
#  'behold view youtub video histori ever',
#  'gon na hit 2 billion',
#  'view youtub video time',
#  '969 210 dislik like dislik',
#  'psi korean',
#  'omg oldspic spraytan parti commerci omg sit real thing omg',
#  'video youtub get much view want see much view 1 000 000 everi day mean peopl think video popular actual get 1 000 000 view',
#  'back quit',
#  '2 billion 2014',
#  'plz check fablif welcom fablif diy challeng plz subscrib thx',
#  'sub channel',
#  'http www ebay com itm 131338190916 sspagenam strk meselx amp trksid p3984 m1555 l2649',
#  'http www guardalo org best funni cat gatti pazzi e divertenti 2013 5287 100000415527985',
#  'like drone plz subscrib kamal tayara take video drone absolut beauti',
#  'http hackfbaccountl com ref 4604617',
#  'what everyon tri showcas talent world 3000 subscrib promis dont suck pleas spread cover around subscrib amp share thank much support luca trigo stay awesom',
#  'gt gt gt gt http www facebook com video php v 10200253113705769 amp set vb 201470069872822 amp type 3 amp permpag 1 lt',
#  'hi group leader angel rooki korean pop group four member chanicka juli stephani leah pleas feel free check channel leav feedback cover video critic welcom know top notch singer pleas come leav construct feedback video appreci chanc improv audit korean manag compani plan audit jyp bighit jellyfish yg sm thank take time day read',
#  'http woobox com 33gxrf brt0u5 free cs go',
#  'admit came check number viewer',
#  'come check peopl still view video appar still',
#  'check first video',
#  'check channel',
#  'psi gangnam style v http youtu 9bzkp7q19f0',
#  'suscrib channel pleas xd lol',
#  'wow comment section still activ bad also 5277478 comment 79',
#  'http binbox io 1firo 123',
#  'ching ching ling long ding ring yaaaaaa ganga sti fuck',
#  'http www indiegogo com project clean pan 2 pleas halp project',
#  'one video channel brother',
#  'check channel pleas',
#  'anyon use gift card like amazon itun psn googl play itun gift card happi know get free gift card code free amaz site 50 itun gift card code xxbb5tczhm39hvzd',
#  'video mani view asian thing awesom non asian countri jelli tri learn asia look video',
#  'plizz with channel',
#  'made game channel uniqu right l angri minecraft',
#  'pleas help go http www gofundm com littlebroth',
#  'anybodi subscrib get 10 subscrib',
#  'http thepiratebay se torrent 6381501 timothi syke collect',
#  'video half way decent check want',
#  'said video deserv 2billion view keep visit watch viewer',
#  'subscrib itz recap diddl',
#  'screw chines crap dont even understand say speak english like everyon',
#  'need money enjoy http www tsu co emerson zanol',
#  'sub channel visuelgamingznl sub back',
#  'pleas subscrib new youtub need help pleas subscrib subscrib back hoppa hoppa gangam style',
#  'sub dont like song',
#  'weird video',
#  '8 million like xd even subscrib 8 million xd',
#  'ehi guy subscrib channel new youtub play minecraft thank guy subscrib',
#  'hi everyon like music check music channel lexi band upload song cover soon miss pleas subscrib help us lot take one click gt',
#  'song never get old love',
#  'gofundm com grwmp',
#  'hey guy pleas check new googl page mani funni pictur funnytortsp http plu googl com 112720997191206369631 post',
#  '2012bitch',
#  'made china',
#  '5 milion comentar 2 bilion view',
#  '0 zero',
#  'mix psi gangnam style v psi gangnam style v',
#  '2 billion view holi shit',
#  '2 124 821 694 view im person aliv zombi apocalyps greet spoderman',
#  'suscrib channel pleas',
#  '2 124923004 wiew wow',
#  'guy pleas subscrib help channel grow pleas guy',
#  'great music anyway',
#  'psi gangnam style v http youtu 9bzkp7q19f0',
#  'crazi 2 billion view us uk korea republ asia',
#  'discov beauti song young moroccan http www linkbuck com acn2g',
#  'like get gift card hate spend cash tri juno wallet juno wallet earn money gift card nike gamestop amazon ebay etc amp easi earn money simpl task like watch video download app amp even earn money invit friend join free signup sign today amp use promo code bd3721315',
#  'somebodi wake get 3 billion view',
#  'psi got lot money youtub got 2 billion view view world',
#  'justin bieber gay',
#  'got ta say funni well 2 billion worth funni still click everyth went uphil least jb shit 1',
#  '',
#  'ahhh 2 year ago',
#  'danc danc psi http www reverbn com msmarilynmil',
#  'check starlitnightski channel see epic video',
#  'http www tsu co kodysman plz',
#  'stupid peopl video doesnt 2 billion visit 2 thousand million',
#  'http www gcmforex com partner aw aspx task joint2 amp affiliateid 9107',
#  'check men put allot effort music unfortunatli mani watch',
#  'pl http www10 vakinha com br vaquinha aspx e 313327 help get vip gun cross fire al',
#  'add http www facebook com tlouxmus',
#  'check channel pleas sing cover',
#  'think place promot channel comment section lol',
#  'get free gift card pay pal money',
#  'check pivot anim channel',
#  'follow twitter amp ig killuminati94',
#  'check game',
#  'oppa yeah best song',
#  'http www sunfrogshirt com sunglass world html 24398',
#  'http www facebook com teelalala',
#  'http www twitch tv zxlightsoutxz',
#  'remind song http soundcloud com popaegi wrenn almond eye',
#  'free gift card go http www swagbuck com p regist rb 13017194',
#  'search chubbz dinero readi thank',
#  'follow twitter mscalifornia95',
#  'everi singl type face earth',
#  '',
#  'check channel new song static love',
#  'incmedia org truth meet',
#  'look channel make minecraft pe let play',
#  'found song',
#  '2 billion',
#  'song name',
#  'pleas like http www bubblew com news 9277547 peac brotherhood',
#  'hey guy wouldnt mind chack rap give like il giver 3 vid like',
#  'http www amazon co uk gp offer list b00ecvf93g sr 8 2 qid 1415297812 ref olp tab refurbish ie utf8 amp condit refurbish amp qid 1415297812 amp sr 8 2',
#  'watch video youtub psi gangnam style 2 1 billion view psi gangnam style v',
#  'subscrib subscrib back',
#  'http flipagram com f luka1qmrhf',
#  'christma song visit channel',
#  'http www gofundm com gvr7xg',
#  'subscrib subscrib back plu nice ass lol',
#  'http www chang org p facebook twitter youtub censor julien blanc',
#  'http soundcloud com jackal jame wrap night',
#  'http www surveymonkey com cvhmklt',
#  'pleas give us chanc check new music video channel disappoint',
#  'pleas subscrib',
#  'best funni viral video histori youtub true',
#  'pleas check vidio',
#  'oppa gangnam style',
#  'funni thing 1 700 000 000 view spam bot mean c mon 2 billion view bs',
#  'oppa lt 3',
#  'funni awesom lol aaaaaaa sexi lada',
#  'view video world',
#  'check view holi shit',
#  'dear person read beauti love great day',
#  'http www ermail pl dolacz v3veygin click http www ermail pl dolacz v3veygin http www ermail pl dolacz v3veygin http www ermail pl dolacz v3veygin http www ermail pl dolacz v3veygin http www ermail pl dolacz v3veygin http www ermail pl dolacz v3veygin',
#  'tri new social network tsu new social network special thing share post well fb twitter even get paid registr http www tsu co worldwid life',
#  'guy yellow suit kinda look like jae suk',
#  'peopl new network like fb regist also free differ get paid share comment like post one wast time fb share paid regist make also money everyday post http www tsu co slema13 wellcom everyon',
#  '2 billion view there 2 million peopl world multipl account 1111',
#  'wat da fuck view video youtub',
#  'omg 2 7 peopl watch video 7 billion peopl world 2 billion watch',
#  'say',
#  'mani view',
#  'omg 2 billion view',
#  'subscrib plz plz plz plz plz plz',
#  'http www twitch tv tareko100 follow twitch enter keyword 5800 chanc win realli nice expens gun csgo sell steam market',
#  '2 126 492 636 viewer',
#  'http www tsu co aseri get money',
#  'fantast',
#  'popul world 7 billion',
#  '2 126 521 750 view',
#  'wow 23 min ago',
#  'super',
#  'p e c e amp l v e',
#  'music video get 2 billion view im one watch earth lol',
#  'pleas friend read book repass http www 4share com web preview pdf cjfoftxeba',
#  'subscrib',
#  'still best',
#  'like video youtub',
#  'still watch 2 year later',
#  'hello kind new youtub soon soon go make launchpad video would realli appreci got sub start peopl spot easili dont realli care hate comment dont bother',
#  'lol dunno joke get lot like whatev xd',
#  '2 billion view piec shit r e u k n g e',
#  'gangman sti drop bass',
#  'song ever reach 7 billion view',
#  'im rapper songwrit check video pleas also subscrib thank tell think',
#  'hello 29 24 earth popul world hope great day',
#  'video start whole got dick stuck elev excus thing',
#  'anyon sub channel',
#  'prehistor song',
#  'think smart headbutt face',
#  'dislik one know real music ex enimen',
#  'loool nice song funni one understand love',
#  'like came see mani view song',
#  'pray littl psi',
#  'littl psi 5 month left tumor head miss u lt 3',
#  'follow instagram chri cz',
#  'shit still relev',
#  'lol shit never get old',
#  'say song chang world complet good job psi girl awesom',
#  '0 02 u see camera man glass',
#  'comment wrong',
#  'hate music fuck singer everi koean chainis ana us suck dick',
#  '2 05 hahahahah',
#  'reach 3 billion view decemb 2014',
#  'dumb guy 2 billion view 7 million peopl earth also know 1 1 equal 1 1 1 smarti pant',
#  'peopl say song old point listen suck stfu enjoy music mom old still listen right',
#  'funni thing song made 2009 took 2 year get america',
#  'dont see comment mine',
#  'jap piec shit worthless fish head dont know one like dumb untanlt gook isnt even fucken music fuck sad even thing peopl fuck',
#  'rememb everyon obsess gangnam style',
#  'remov video wank',
#  'hard sad ithat littl child actor hwang minoo danc activ child suffer brain tumor 6 month left hard believ keep pray everyon futur superstar stronglittlepsi fight share everyon pray http ygunit com 2014 11 08 littl psi brain tumor 6 month left live',
#  'fuck keep updat comment 5 minut ago song 2 year 4 month ago',
#  'mani memori',
#  '5million comment 279 898 youtub user 5million fake account psi hack youtub',
#  '2 000 000 000 7 000 000 000 peopl would saw video 2 year yeat get 2 word hole song',
#  'video cool',
#  'go voyag first comment tell famili love',
#  'video youtub get mani view like gangnam style problem understand phenomena behind like random music video',
#  'korean girl slut bitch hyuna 33',
#  'hey guy check kollektivet slappin peni think deserv much credit receiv',
#  'still fun music video watch',
#  'c mon 3 billion view',
#  'hey everyon new channel post video book review music flute pleas subscrib would enjoy thank',
#  'hey think know deal theori could gotten 2billion hit 1 mabey made korea reali popular stuck watch 2 2billion peopl access internet includ youtub number rise 2017 half populatoin connect 3 hacker korea may love much rise 2billion hit make popular 4 song featur danc game multipl mp3 seen concert even new year eve event 2012 see mabey ad hit video 5 complain much heck 2b hit',
#  'subscrib chanel',
#  'view queen michael jackson 2 billion view omg',
#  'lol',
#  'paus 1 39 last millisecond see chick laugh take tri',
#  '9 year old like 2 billion view 3 peopl world',
#  'psi good guy',
#  '2 billion view song annoy',
#  'http www facebook com page mathster wp 1495323920744243 ref hl',
#  '1 millioon dislikesssssssssssssssssssssssssssssssss',
#  'littl psi suffer brain tumor 6 month live pleas pray best luck',
#  'littl kidz like 7 8 billon peopl earth 7 8 millon get fact straight post comment',
#  'stupid human',
#  'come watch video call odowd crowd zombi movi part 1',
#  'know song suck dick need use googl translat know fuck say',
#  'get came view',
#  'wow video view youtub video second come justin bieber babi smh world come',
#  'hey join ts publish platform share content http tsu co markusmairhof',
#  'song great 2 127 315 950 view wow',
#  'watch 2014',
#  'view video youtub daaaaaaaaaaannng view almost domin entir china',
#  'video 2 127 322 484 view 7 million peopl earth',
#  'gangnam style',
#  'lol youtub officialpsi get much money lol',
#  '1 million dislik epic fail readi fanboy',
#  'knew korean would even funnier least bit end english spoken quit rapidli',
#  'enough whole two billion view 7 million planet get joke funni anymor',
#  'get 100 subscrib summon freddi mercuri ghost whipe face earth one direct miley ciru',
#  'reach 100 subscrib go round public pour bucket ice water peopl run away act like like peopl see',
#  'youtub money',
#  '2 billion shit',
#  '2 billion view 2 million share',
#  'hi guy name dylan irl footbal video 1030 subscrib think guy would like content come check subscrib',
#  'get 300 subscrib tomorrow epic hunger game video',
#  'follow pleas http www facebook com list 161620527267482',
#  '2 billion view wow even babi justin beib much deserv capit name',
#  'reach 100 subscrib tazz self friend',
#  'pleas help go colleg guy thank bottom heart http www indiegogo com project want go colleg 19 x 9082175',
#  'http www facebook com schoolgeniusnit photo ms c ejw9kvkoxdamqm808h5z 4snjqp thqbeum69aqup1ih fphgk5zllsvdqv0zuf0mb lnuj ufth4yokfrxyts2zvrrp6qgtw67i l551h f7 vlczzrg8vgctlpsd9ongewhj8 gibu s3lzmvi iq2 twsfzz9whn7jusvhufpglqrzczl05fnphagevb3x8ydmc6x jtcjnmho vfxwcjzyvwobihrngx2ocjng2pg1evhxzyjd o3h ry6f57sprnd2xv bzszz 8 bp 390875584405933 391725794320912 type 1 amp theater',
#  'awesom smart sucscrib',
#  'follow 4 follow vaahidmustaf like 4 like',
#  'http hackfbaccountl com ref 4436607 psi news cal',
#  'http www facebook com nicushorbboy add mee lt 3 lt 3',
#  'im sorri spam name jenni go high school everyon dress fashion need money buy cute cloth low self esteem live dad mom pass away 6 realli mother figur 2 brother older sinc boy get attent alon realli want wear pretti cloth like girl school get boyfriend self im quit shi school confid talk someon one friend name carolin move away im alon could donat money would great care expens brand ill shop walmart pretti cloth also wan na get nail done salon see alot girl french tip never nail salon realli appreci get hair curl http www gofundm com dressprettyonc thank omg pleas',
#  'hate song',
#  'pleas throw sub channel',
#  'new goal 3 000 000 let go',
#  'go channel u want see fli get burn aliv',
#  'came check view p',
#  'come check new youtub chhanel go post daili',
#  'hav absolut idea say even languag',
#  'pleas check vidio guy',
#  'still day wonder video popular illuminati confirm',
#  'hey guy check channel plz mine craft video let shoot 20 sub',
#  'get old',
#  'pleas subscrib',
#  'came check view count',
#  'check music video fuego u la la remix hyperurl co k6a5xt',
#  'check music video pleas subscrib fuego u la la remix hyperurl co k6a5xt',
#  'www marketglori com strategygam lordvipera',
#  'shitti chines govern block youtub close 3 billion view right',
#  'world record youtub video view xd',
#  'think drunk x',
#  'limit sun exposur drive elimin hassl swing car visor windshield window http www kickstart com project 733634264 visortwin',
#  'hahah juyk allway laugh part 1 57 lol',
#  'http hackfbaccountl com ref 5242575',
#  'want know name guy danc 00 58 anybodi know',
#  'http www facebook com fudairyqueen pnref stori',
#  'haha funni see salt western top view youtub goe video dont even understand keep salt',
#  'follow compani twitter thank http twitter com thewaxedhatco',
#  'imagin guy put adsens view u could pay ur morgag',
#  'hey come check us new youtub let us know think forget subscrib thank',
#  'girl train danc outfit fuck sexi huge turn lack eyebrow',
#  'look pictur difficult http image2y ru 48051 1340524 http image2y ru 48051 1340523 http image2y ru 48051 1340522 http image2y ru 48051 1340521 http image2y ru 48051 1340520 http image2y ru 48051 1340519 http image2y ru 48051 1340518 http image2y ru 48051 1340517 http image2y ru 48051 1340504 http image2y ru 48051 1340503 http image2y ru 48051 1340502 http image2y ru 48051 1340500 http image2y ru 48051 1340499 http image2y ru 48051 1340494 http image2y ru 48051 1340493 http image2y ru 48051 1340492 http image2y ru 48051 1340491 http image2y ru 48051 1340490 http image2y ru 48051 1340489 http image2y ru 48051 1340488',
#  'mind check view',
#  'hey guy check youtub channel know hate comment like one promis check video entertain shotgun montag ninja defus montag troll pleas guy check thank good day',
#  'everyon joke hack get 2 billion view certain amount peopl whatev actual buy view',
#  'http www facebook com tofikmiedzynb photo 1496273723978022 1073741828 1496241863981208 1498561870415874 type 1 amp theater',
#  'http www facebook com eeccon post 733949243353321 comment id 734237113324534 amp offset 0 amp total comment 74 pleas like frigea mariu gabriel comment',
#  'http www bing com explor reward publ referafriend amp crea raw amp rrid 0f9fa8aa 243a 5c2f c349 ede05ea397ca bing reward earn free money u cant get ur viru blue',
#  'pleas buy new christma shirt buy time decemb 4th sold worldwid miss http teespr com treechristma',
#  'free app get 1m crdit click link download app done link http freemyapp com share url 5af506e1',
#  'song like view michael jackson smh',
#  'someth danc even sad danc psi gangnam style v http youtu 9bzkp7q19f0',
#  'everyon back lool almost 3 year old peopl still hear xd',
#  '2 billion view planet lol',
#  'watch 2014',
#  'subscrib call duti vid give away goal 100 sub',
#  'hi guy pleas android photo editor download thank http play googl com store app detail id com butalab photo editor',
#  'first billion view thought realli cool billion half came see stupid first billion',
#  'love much also gener free lead auto pilot amp http www myleaderg com moretraff',
#  'http www billboard com articl column pop shop 6174122 fan armi face round 3 vote sone pleas vip pleas help us gt lt',
#  'hey guy pleas join fight help abus mistreat anim fund go help pay vet bill help find home place extra emphasi help disabl anim one otherwis would put sleep anim organ donat pleas http www gofundm com angel n wingz',
#  'http psnboss com ref 2tggp3pv6l song',
#  'hey everyon watch trailer http believemefilm com hlr h2hqbuvb',
#  'check rap hope guy like http soundcloud com nereboy call lostproduc atlastatla rapper jkork follow messag',
#  'subscrib pleaaaas instagram account subscrib back http instagram com cyrin ghorbel',
#  'hey guy visit channel pleaas search dream',
#  'nice http www barnesandnobl com bdp csrftoken i9tixe8cnkcosoqkemgjlu5uwv6nsxso amp sort dd amp size 90 amp csrftoken 89iyec7nrwp5nytno5u7amhvmflutggl amp dref 5094 amp keyword bdp amp store ebook',
#  'http www twitch tv daconnormc',
#  'hey guy glamour beauti start youtub channel pleas go check go post sing video also random video fell like pleas go subscrib come soon rememb subscrib',
#  'hey guy mom said got 100 sub christma get kitten alway want kitten pleas watch video like subscrib like pleas mean comment',
#  'http www facebook com photo php fbid 543627485763966 amp l 0d878a889c',
#  'http www facebook com photo php v 4483179854075 amp set vb 1727483389 amp type 2 amp theater',
#  'http soundcloud com artadi pleas check stuff make feedback',
#  'take break kati help reach 100 subscrib month new music free download',
#  'subscrib pleas',
#  'check cover video come pleas subscrib',
#  'subscrib channel',
#  'hey guy small youtub upload video nearli everi singl day hope like shika pleas give 2 min life view channel new video watch anim free pretti sure wont regret visit channel thank',
#  'http www rtbf tv emiss detail voic belgiqu tout le audit auditiondetail emissionid 3873 amp id 342 pleas join voic like share pleas win audit score thank much',
#  'kati perri u sit face pleas would realli awesom give 5 dollar ok want pleas call subscrib channel first ok that good u sit face ill get erect sit k',
#  'top 10 youtub top view 9 miley cyru http www googl ro url sa amp rct j amp q amp esrc amp sourc web amp cd 1 amp ved 0cb8qfjaa amp url http 3a 2f 2fen wikipedia org 2fwiki 2flist view youtub video amp ei oq3yu9dwc8l4yqoyo4goaw amp usg afqjcngkm idplal6kuvkoekvgdtt2jvlq amp sig2 onqzzad3q3cmnbe9nml4ga amp bvm bv 73231344 bgq amp cad rja',
#  'http www amazon com knight dawn curs daniel n ebook dp b00mppqhri ref sr 1 7 digit text amp 3bie utf8 amp 3bqid 1408122684 amp 3bsr 1 7 amp 3bkeyword knight amp tag wattpad 20 peopl talent talent sponsor',
#  'realli love video http www bubblew com account 389088 sheilcen',
#  'hi guy check awesom edm amp hous mix thank lot http soundcloud com soundhas edm hous mix 2',
#  'hiya start youtub would mean lot could subscrib watch first video xx',
#  'watch maroon 5 latest 2nd singl v alway www youtub com watch v tq046fuau00',
#  'help pleas http www gofundm com rjanimalcar',
#  'http www mediafir com download yvovhafsv5qzzqo video rar download make money today',
#  'http www ebay com itm 131275322914 sspagenam strk meselx amp trksid p3984 m1555 l2649',
#  'lt script gt document write lt target self href http rover ebay com rover 1 710 53481 19255 0 1 icep ff3 1 amp pub 5575096797 amp toolid 10001 amp campid 5337555197 amp customid bogdan grigor amp ipn psmain amp icep vectorid 229508 amp kwid 902099 amp mtid 824 amp kw lg gt check new ariv ebay lt gt lt img style text decor none border 0 pad 0 margin 0 src http rover ebay com roverimp 1 710 53481 19255 0 1 ff3 1 amp pub 5575096797 amp toolid 10001 amp campid 5337555197 amp customid bogdan grigor amp mpt math floor math random 999999999 gt lt script gt lt noscript gt lt target self href http rover ebay com rover 1 710 53481 19255 0 1 icep ff3 1 amp pub 5575096797 amp toolid 10001 amp campid 5337555197 amp customid bogdan grigor amp ipn psmain amp icep vectorid 229508 amp kwid 902099 amp mtid 824 amp kw lg gt check new ariv ebay lt gt lt img style text decor none border 0 pad 0 margin 0 src http rover ebay com roverimp 1 710 53481 19255 0 1 ff3 1 amp pub 5575096797 amp toolid 10001 amp campid 5337555197 amp customid bogdan grigor amp mpt cachebust gt lt noscript gt',
#  'votekatyperri 2014 mtv vma best lyric video see lead vote http mtv com ut15kx',
#  'http www facebook com page d8 aa d8 ad d9 85 d9 8a d9 84 d8 a7 d8 ac d9 85 d9 84 d8 a7 d9 84 d8 a7 d9 85 d9 88 d8 b3 d9 8a d9 82 d9 89 music 674732645945877',
#  'hello marian singer venezuela part boy girl band name cubik sing caus want play pop pop rock song would mean lot could look channel check music watch new video u like subscrib xoxo thank ps like lot channel share friend haha lol marian',
#  'kati perri remind tiger like spirit anim 3 lt 3',
#  'south american jungl jungl matter find african eleph bengal tiger place made video',
#  'http 9gag com gag aavpwj9',
#  'ima rapper tri get notic pleas check mixtap datpiff com mixtap detail php id 633807',
#  'good song like video clip bout girl airplan crash land far far away found way surviv love pet tiget kitti purpi lol',
#  'help click subscrib mai nguyen thank',
#  'even without make still hot http uk eonlin com eol imag entir site 2012430 reg 1024 kati mkup mh 053012 jpg',
#  'thank video know nokia phone surviv plane crash',
#  'http www bubblew com news 6401116 vp solut',
#  'treu detect altern end http www funnyordi com video d15fb87973 true defect',
#  'new makeup transform integr look like featur avail ver 1 13 know look like instal updat version makeup transform http play googl com store app detail id com yourelink makeuptransform visit googl play',
#  'name tiger kitti purri serious check video',
#  'perfect lt 3',
#  'video end 13 ft boa constrictor squeez death',
#  'paus music clip movi',
#  'hi twin melodi 17 year old twin cover cover birthday kati perri pleas take 1 second watch thank merci gracia dank obrigado grazi lt 3 xx nice day',
#  'nice sabrosura viva http soundcloud com yerki elinmigrant yerki myb move bodi',
#  'hey guy go check video name growtopia stori',
#  'http shhort com r hupweh5ab',
#  'yay im 11th comment crazi pleas donat bitcoin 1fhenqx1twqm153v2ptayiejnealahzvem',
#  'http shhort com r g8ix5ctkd',
#  'love song empow everi woman gon na hear roar',
#  'song make want drink bleach',
#  'realli hardcor',
#  'http shhort com r jt2ufxhxc',
#  'follow watch video follow watch video follow watch video follow watch video follow watch video follow watch video follow watch video',
#  'sorri kati perri weird still love lt 3',
#  'big fan song video awesom',
#  'kati perri stop dont song dont like',
#  'go channel check written song',
#  'like gorlin goltz syndrom support commun alon http www facebook com gorlingoltzsupport',
#  'subscrib u gon na hear roar',
#  'opinion think look better black hair blond hair',
#  'love amaz omg eye',
#  'pleas help give son grave http www gofundm com bishopsgravemark pleas share fb page one anymor',
#  'gon na hear roarrrr',
#  'follow gt http twitter com f0llowshoutout',
#  'finish dissert laugh face finish roaaarrr 3',
#  'old whore',
#  'pleas share help friend http www gofundm com jormi thank much',
#  'roaaaaarrrrrr',
#  'look fun good song',
#  'check vid song awesom guarante',
#  'love kati',
#  'love much get stand fear',
#  'click itun code http shhort com r 0laviqu2b',
#  'kati perri inspir singer voic awesom love much achiev music histori believ guy could take 1min go channel watch first video would greatli thank ty guy n kati still awesom xoxo',
#  'hi guy sell jack daniel hard back cover case iphon 5 5s 5c 4s 4 6 old time 3 dollar ebay http www ebay com itm 251638183951 sspagenam strk meselx amp trksid p3984 m1555 l2649',
#  'http facebook com stori php stori fbid 764484966942313 amp id 754989901225153 amp ref stream gf',
#  'subscrib',
#  '3 46 cute',
#  'think drunk shot first half video sec half come boob magic bigger beauti suddenli dude practic vanish',
#  'roar without doubt best song feel good song messag everyon good job kati',
#  'great mother jungl sweet natur like video',
#  'http www aaa org tech vote view 25874 2177367 vote sheldon pleas guy give 5 star thank advanc',
#  'kati conqueror haki gt',
#  'check video pleas hate give one oportun',
#  'wow nice congrasul live much http en prothom alo com sport news 53331 zimbabw team due dhaka wednesday',
#  '7 bilion poepl earth stop dumb',
#  'love shit dislik suck',
#  'hey guy realli want go kati perri concert im contest need lot like im loos pleas could like pictur would nice thank realli want go concert http www facebook com exagdl photo 936868579660284 1073741943 111719098841907 937732262907249 type 1 amp theater',
#  'video inaccur tiger would rip face',
#  'great video great artist kati perri admir creativ check channel nonsens mobil tech review comparison well iphon 6 6 plu review comparison',
#  'real anim',
#  'hey guy pleas subscrib channel gon na film video hope guy like thank much support xoxo leah lt 3',
#  'mayb best music video last 15 year pop music done folk',
#  'love kati perri lt 3 lt 3',
#  'boooob',
#  'realli understand 600 million view lol hate anyth confus',
#  'almost kati birthday octob 25th let say happi birthday kati',
#  'kati perri look soo pretti damn cute',
#  'great song go kati',
#  'looooooooooooooooooooovvvvvvvvveeeeeeeeeee ittttttttttttt',
#  'telephon',
#  'comment randomli get lot like repli reason also like jello strawberri jello',
#  'hey guy made amaz smiley shirt thing wear express import rememb statist world measur warmth smile big fan shirt want get happi perfect check buy www teespr com smiley12 thank guy much',
#  'realli want video get 1 billion view would amaz',
#  'kati voic gold video realli bring lyric life rapper 25000 subscrib thumb hate take shit water splash nut',
#  'start hate kati perri find stole idea video old comic book yet music catchi',
#  'song 629 million view 7 million peopl world',
#  'kati perri garbag rihanna best singer world',
#  'http www reverbn com slicknick313 song',
#  'kati perri part kati perri firework kati perri love',
#  'song good got overplay hell radio',
#  'see human folli right',
#  'great song',
#  'awesum song ju luv',
#  'watch video xx',
#  'pleas check acoust cover channel thank',
#  'imagin news crazi woman found act like tiger bit jim ear',
#  'selfi alert',
#  'go hear roar soundsofsunday',
#  'shit',
#  'love vena trojmiasto pl vena bu taxi o59253 html',
#  'competit meet idol would mean much guy like pic ig http instagram com p smzdivopxb',
#  'katti perri pleas say one new video follow girl girl pleas',
#  'big fan love',
#  'http viralangel com user d4aaacwk',
#  'lt 3 kati perri',
#  'sinc feminist champion would want reinforc stereotyp girl girli paint nail eleph probabl even appreci',
#  'http thepiratebay se torrent 10626835 expend 3 2014 dvdscr xvid dingo',
#  'http thepiratebay se torrent 10626048 expend 3 2014 dvdscr leak clean xvid mp3 rarbg',
#  'interest make extra money internet use next link www swagbuck com refer nonturtle02',
#  'fuck shit first note becom clear complet utter shit may god come cleans earth complet utter idioci humankind',
#  'hey guy plz check youtub channel c funni 2 girl 1 cup reaction thank plz subscrib thank',
#  'pleas subscrib everi sub get shout tell type video u want tri make happen',
#  'hey guy subscrib channel reason pleas',
#  'katycat http facebook com profil php id 1461302180794905',
#  'least get rid complet useless makeup',
#  'love roar kati perri favorit singer sometim mute volum look',
#  'best best video world',
#  'got incred voic extrem hot nice tit',
#  'gt attent katycat kati lead 7 nom year mtv ema vote daili tv mtvema com vote delet space thumb share fb',
#  'realli like song',
#  'son love much',
#  'love',
#  'follow instagram bigboss286',
#  'eleph broken horn',
#  'free itun 25 giftcard code http shhort com r oocnjqu2b',
#  'find make freakin jungl',
#  'cute monkey',
#  'nice song',
#  'subscrib pleas',
#  'sheep period terribl music',
#  'friend mine invent big dick formula small dick 4 inch research topic research found secret knowledg peni enlarg appli learn 7 inch dick absolut amaz result cours took month therefor written book issu order help guy ask promot book guy interest info check http payhip com b otib sell symbol 1 thank',
#  'begin scare everyth next thing know leopard bikini',
#  'pleas look channel',
#  'three bigger secret think good enough skinni size bisexu sweat realli freak bad nervou check secret austin mahon new singl',
#  'http www facebook com page nailey nicool 629410220489046 ref hl like mee',
#  'kati beauti song catchi rapper 25000 subscrib thumb hate take shit water splash ball',
#  'love green eye',
#  'old kati perri',
#  'popular video youtub',
#  'nokia spot',
#  'hear time radio realli irrit said like video',
#  'hi everyon dream passion sex kati perri peopl believ mayb sex giant part life push better person pleas give chanc give thumb love ambit pleas subscrib',
#  'fantast',
#  'j aiiima plzzz http www facebook com page c3 89c c3 b8l ce b5 al ce b7b ce b5t 302703146601369',
#  'http vimeo com 107297364',
#  'awesom xd',
#  'kati perri song bad',
#  'hi beati made new channel pleas go check subscrib enjoy',
#  'http www facebook com page hiphop express 704682339621282 like page yo',
#  'beauti bella diagnos wobbler syndrom way could afford mri surgeri dog special member famili without surgeri fear lose pleas help http www gofundm com f7ekgw',
#  'http www facebook com page komedi burda gel 775510675841486',
#  'http www facebook com profil php id 100007085325116',
#  'good',
#  'http www googleadservic com pagead aclk sa l amp ai csyoeb1wxvpcfl7d27abgpydgbjdpm6ih6mhu05wbgjxbv8sbeaegkn7ljvcf7byh f 8byiofgicahkabskg31wpiaqkpah kmc0hbpm qambyapbbkoekwfp0kullxqi1mg6o43hvz efmqrg4tu5llbu fsz8gn0hbkjhbx m83w1ts3 3dx hwpdx1kazsj8o7siecvjjmbnswyijecqvhxlbdzstubofaloyinwm0 roocpps2auat6zguickm0li83duwmabzqvene8trfazorltbb037vzyv xi4hbnq2nvh19mrbge0sibgggbgkab7jeycg amp num 1 amp cid 5gg 9ma3ti40fs6mvp amp sig aod64 1ofc7seh 1pop jyrbs7x6 heenq amp client ca pub 8252267209931889 amp adurl http blog 2paral ro 2014 10 challeng pentru afiliati aplica la noil program de afilier si fii busi boomerul lunii amp nm 2 amp mb 2 amp bg a0qouc7q48v3 qiaaabpugaaacsqar0 vgoqwqxjmpuyvkosf3k q1bvkf9ze4jhnc3ovckkxcbafzzpajibxwbvvq4jrdgz8q3rinlwgabi bxlfw7ma6dk0rjg14zkryizwqdi7hxgge9tndd9abfltfkbmbffcjixnthwbwkj6n2onlh2d9eveagphoewxogbnu5ibgtrkgnacq1oibgmzgafnsc0lsariqj8hqr8t12dwv 7biy4k6i3y4yublotd 4xvklnveadzzf1l xryqke6wsur3edljwgk8flq qaldi waznuysgqjnrdy6vucklplzonyisdkc9ebx 0dbhjzdw0lbsjbi40gxm0d0p5krhv8xinqli53 wqbahs8zx4mjhw5vwrkpxfoek',
#  'awesom video one favorit song',
#  'bodi like kati perri look hot love',
#  'download rapid facebook free http play googl com store app detail id com rapid facebook magicdroid',
#  'song good video make sens nonsens video mean tell stori stuck island song fit situat nvm song good',
#  'els would give kati perri good old mighti roar',
#  'omg love kati parri song rock that total subscrib',
#  'http www paidvert com ref tomuciux99 esyest money ever join team',
#  'kati perri roar offici http youtu cevxzvsjlk8',
#  'free itun gift card http shhort com r x6j4gbrne',
#  'play song babi belli start danc sooooo cute take song caus copi right add youtub made song still sooo cute babi danc song lmfao http plu googl com 111982027348137311818 post g2jvinpuemo',
#  'kati perri awesom',
#  'song addict hook dope catchi love video get popular fast rap real thumb piss next water toilet quiet',
#  'nice song see new track',
#  'love sooooooooooooong love kati perri',
#  'tattoo right tricep say',
#  'sinc kati perri youtub channel',
#  'everi time watch mv glad live world worri run real human eat tiger',
#  'rekt ur mum last nite cuz da haterz 2 much 4 meh lik di u cri evertim sponswer mi robox vidz http www indiegogo com project gim dem moneyz 4 roblox x 8851222 home',
#  'eye tiger champion seem like kati perri use titl old rock song lyric',
#  'perfect wonder',
#  'http www indiegogo com project help stop poverti cyber pan handl x 8692160 home',
#  'horribl act cring worhti',
#  'love kati fashion tiger care visit blog sinar jahitan also tiger collect tqvm',
#  'anyon love music pleas go check youtub page tell think put video song tri get start love much appreci',
#  'tiger call katti purri',
#  'blue eye trust uranu bless america',
#  'rap belaru check channel',
#  'follow twitter freyacumqueen',
#  'kati perri roar offici http youtu cevxzvsjlk8',
#  'c mon kati close 14 000 000 subscrib come anoth hit like happen',
#  'vote kati ema katycat http tv mtvema com artist kati perri i38xh1',
#  'honest opinion mediocr song noth uniqu special music lyric voic noth memor like billi jean beat million fan repli hate comment know democraci peopl free see want right express opinion pleas repli dumb comment lie like watch came see buzz 661 million view like saw ok',
#  'visit channel',
#  'wow sexi xd',
#  'look new music listen check cece song call dead2m itun music video right youtub',
#  'kati voic angel',
#  'hey guy work last night project music streamer like spotifi allow download file listen offlin open free beta feel free tri download http mega co nz ehvjzkya 5bgkg2iwphzohwaeuesrwnegqg labco7rw9wfx8hao',
#  'man hot one male companion visit profil check coolest sextoy ever made',
#  'like page pleas http facebook com dreaddi ref notif fbpage fan invit amp actorid 1442646731',
#  'video racist anim',
#  'man beauti',
#  'want win borderland pre sequel check channel',
#  'hi would appreci could help like poster facebook http www facebook com nyghdramafest2014 photo 333608120156973 1073741830 327568907427561 333607726823679 type 3 amp theater',
#  'plz help get 1 000 subscrib tonight today thank sub',
#  'yesterday video 1 million like 2 million',
#  'tiger succumb beauti girl probabl male tiger ha ha ha',
#  'best song ever',
#  'thank katyperryvevo instagram like axeljonsson',
#  'pleas subscrib channel',
#  'good make music',
#  'love katti perri lt 3',
#  'honestli wan na see brave oh wait',
#  '',
#  'video great love like much kati perri',
#  'good thing brought spray tan hairstylist makeup artist cameraman',
#  '666 002 018 view 666 million 666 kati perri illuminati confirm',
#  'make guitar cover pleas look channel',
#  'illeg goodlook babe',
#  'kati mine girl dream',
#  'love song',
#  'fit',
#  'love song roar make think fill way',
#  'forget choic fuck surviv plane crash 1 1000 chanc happen',
#  'fool foolish video lyric great arrog obvious thing lot idiot look mani hit garner young stupid girl listen number million guess video piec trash would anyon ever like listen stupid littl girl idiot father mother go turn idiot also like stupid singer',
#  'attent need 10 million view firework reach 500m 1 half day left kati birtgday listen could possibl gt gt open differ tab differ browser gt gt dont watch full video rememb dont time hand time wast view 30 sec plz thumb share',
#  'rapid facebook free version color character fast beauti download http play googl com store app detail id com rapid facebook magicdroid',
#  'hey katycat releas movi midnight uk time celebr kati 30th birthday sure subscrib channel watch movi',
#  'realiz vers song exact melodi vers hey ho lumin',
#  'favorit song',
#  'song never get old lt 3',
#  'happi birthday kati http giphi com gif birthday flower happi gw3jy2uqiaxkaqx fullscreen',
#  'hey know peopl like kind comment amp see spam see free advertis pleas check cover spark fli taylor swift best ever know mayb encourag word wisdom mani becom better pleas go channel check',
#  'www youniqueproduct com joannagordon youniqu joanna gordon www youniqueproduct com',
#  'like kati perri 600 60 6',
#  'glad know im one know katheryn birthday today happi birthday kati sister serious birthday',
#  'kati perri sing shit hear autotun',
#  'fuck hate write song got produc second tha fack everi song almost nude maybi attent hooker',
#  'also luckymusiql probabl could help u make big think u talent look name internet hit u get messag',
#  'check drum cover e thank gt watch v no9povz9oiq amp list uultucdihsdei01by1ow7wuq',
#  'put famou peopl jungl hour look happen',
#  'kinda let go huh',
#  'love kati perri lt 3',
#  'sign free tsu start make money social media add follow ill add follow http tsu co roberts9010',
#  'love relat daughter music kati perri roar offici http youtu cevxzvsjlk8',
#  'subscrib subscrib back',
#  'kati perri roar offici soundsofsunday music',
#  'hear kati sing cri song got depth',
#  'love',
#  'peopl believ illuminati stupid peopl believ 911 made american govern',
#  'plz subscrib channel need sub sub back need help',
#  'pleas look dhg song playlist bunch amaz song',
#  'hey nerdi peach new youtub would mean absolut world could check em lt 3 hope like',
#  '00 39 im pretti sure tiger want hug',
#  'http vimeo com 106865403',
#  'song give strength love lyric video realli bring lyric life get known fast rap mean thumb piss next water toilet quiet',
#  'http minhateca com br mauro sp2013 film seri desenho anim mp3 etc',
#  'http www facebook com antroboffici',
#  'love kati perri sing nice shakira',
#  'http hackfbaccountl com ref 4344749',
#  'facebook account hack http hackfbaccountl com ref 4477063',
#  'love katti perri',
#  'perri good job good job love video way pleas describ channel pleas pleas pleas pleas tri get mani comment skyburst light cancer get famou pleas',
#  'cover u want check thank u michael age 8',
#  'everybodi pleas vote kati ema 2014 best song best femal best pop best live best look best video pleas vote kati pleas pleas pleas vote vote vote kati kati kati',
#  'h god roar like video vevo 2 month ago justin babi congrat kati applaus lt 3',
#  'http soundcloud com j supt fil du son fuck hostil',
#  'http www facebook com myfunnyriddl',
#  'hi everyon like music check music channel lexi band upload song cover soon miss pleas subscrib help us lot take one click gt',
#  'http www facebook com photo php fbid 313454548839369 amp set 207230212795137 1073741825 100005244783212 amp type 1 amp theater 1111111111111111111',
#  'rather hear propa explicit gangsta rap inst garbag song trash',
#  'damnnnnnnnn sexi',
#  'good song an kati sound great melodi im grow artist everyday hit song crazi got name cant thank fan support could take moment check music mayb join make dream come true thank time',
#  'love u make smile im sad cheer beauti song lt 3',
#  'song bore asinin song ever heard come guy like teenag dream song ever sinc kati perri divorc wave wave shitti success song say next wave pop music stick ass kati perri like silli putti',
#  'kati perri roar offici http youtu cevxzvsjlk8 love song video kati perri rock wahoo',
#  'somehow access makeup middl wood',
#  'look real daughter big fan like lot song',
#  'comprehend video nearli 700 000 000 view peopl found gangnam style funni explain high view count aw pop song realli clue one',
#  'let honest last 1 day jungl stop live n fairi world',
#  'segu ha http www facebook com marco sousa4 fref ts',
#  'natur beauti need place tit video impress peopl',
#  'stupid roar lion real life dede',
#  'song awesom made everyth stand viewer could imagin set video awesom job kati perri',
#  'kati perri roar offici http youtu cevxzvsjlk8',
#  'kati perri lion',
#  'peopl new network like fb regist also free differ get paid share comment like post one wast time fb share paid regist make also money everyday post http www tsu co slema13 wellcom everyon',
#  'figur dislik song suppos power ballad right someth uplift motiv end howev final choru extra umph end actual sound like first one instead crescendo ing power finish roar say wavelength fall flat',
#  'like song video goe perfect',
#  'champion gon na hear roar today champion today champion creator today posit world today bless heal around today success creat success',
#  'nowplay weekendmix track 04 kati perri roar dj deni shmelev amp dj alex serov remix http youtu cevxzvsjlk8 listen live www smartfm nl livestream html',
#  'kati perri song best song women artist',
#  'like song anim like song',
#  'http www wattpad com stori 26032883 love good',
#  'love song much heard much pretti much memor lyric',
#  'hey guy know tend skip comment take look first free fire big room progress hous deep hous dubstep amp chillstep produc small town missouri support commun realli ask critiqu support view music gotten much better 10 month ago promis new content satisfi soon abl advertis wont pester guy anymor gim chanc check music thank god bless',
#  'latest movi 2014 pleas visit site http www networkedblog com p 11cpwb ref panorama',
#  'love subscrib',
#  'http www tsu co tomek go regist free money',
#  'great song know kati buy view',
#  'check mah girl duh shit yo',
#  'check video youtub facebook lhudygirlamaya',
#  'hey yall real kevin hart shout fan follow realkevinheart',
#  'check acoust channel',
#  'know someon see dream greatest video best qualiti right feel like get anywher need help could possibl watch video mean world pleas thumb other see appreci much pleas listen hate honestli appreci much love give 17 year old chanc',
#  'http app facebook com poll utsitcompetition2014 user link amp ref id ouxg5 pleas open link vote anand niketan intern school project name project fr e dom share friend',
#  'hate video like poor anim',
#  'hii youtub',
#  'nice nice',
#  'love song',
#  'kati shit go die roar floooooooooooooooooooop',
#  'love music',
#  '6th grade teacher look exactli like kati perri come think',
#  'curti click http www facebook com demiilovatofa ref hl http www facebook com page frase secreta 448800865296855 ref hl',
#  'http www ermail pl dolacz unnfy2i pleas click link',
#  'come check parodi',
#  'pleas subscrib us thank',
#  'pleas vote wet seal model 2015 contest instagram usernam destinyforev http www wetseal com modelsearch15 modelsearch15 html',
#  'simpli put custom love us http www facebook com greenlead',
#  'http binbox io dnckm qt4q1jb1',
#  'almost 1 bil wow gs suck opinion',
#  'katti best',
#  'good mean much good',
#  'song mean much thank soooooooooooooooooooooooooooooooooooooooo much xxx',
#  'lt 3',
#  'kati perri cio cabelo decio hair 60 year age famili singl alon homeless alcohol 15 age 46 invis compos dream record song could help pleas pleas trust give chanc 109 video youtub deciocabelo canal kati perri born octob 25 thank much decio hair',
#  'honestli speak except taylor swift adel lile modern day singer must say whenev hear song feel goosebump quit inspir thank miss perri',
#  'go reach billion first kati taylor',
#  'href http www youtub com watch v kq6zr6kcpj8 amp 2m19 2 19 best part',
#  'wierd funni',
#  'hey guy 39 human br br br 39 want human want sexi fuck giraff br br br alreadi money surgeri elong spinal core surgeri chang skin pigment everyth els like post other root dream br br br im fuck make music check first song rel nofollow class ot hashtag href http plu googl com 23giraffebruuh giraffebruuh',
#  'parti rock lol want shuffl',
#  'parti rock',
#  'shuffl',
#  'omg',
#  'song realli fun',
#  'awsom br',
#  'wow increibl song',
#  'love song much',
#  '2015 likee',
#  'miss peopl dress like',
#  '2011 last year decent music',
#  'best song ever',
#  'super nice love musiqu',
#  'wowwwwwwwwwwwwwwwwwwwwwwwwwwwwww',
#  'parti rock 8',
#  'thumb watch 2011',
#  'increidebl',
#  'lmfao',
#  'superr',
#  '2015 llike',
#  'yeah let 39 start parti',
#  'awesom song need 4 year reach 800 mil view tango switch bitch need 1 year fairrrrrrr',
#  'nice girl',
#  'rememb back popular everyon school shuffl crazi',
#  'lmfao',
#  'super awesom video br',
#  'danc 3',
#  'alway favorit song br favorit part href http www youtub com watch v kq6zr6kcpj8 amp 3m40 3 40 href http www youtub com watch v kq6zr6kcpj8 amp 4m11 4 11 video',
#  'parti rock br',
#  'lmfao parti rock anthem ft lauren bennett goo href http youtu kq6zr6kcpj8 http youtu kq6zr6kcpj8 br box man got move make meh smile',
#  'best song ever hire br',
#  'funni mahogani lmao actual 39 know brother uncl part lmfao',
#  'parti rock anthem love parti rock anthem life',
#  'stop top 1',
#  'ahhh back life 39 suck',
#  'parti rock xd',
#  'cute',
#  'lmfao best song ever',
#  'fuckin love song br br br 39 sexi know',
#  'shuffl hard made earthquak nepal',
#  'nice',
#  'still remind 1 year back shuffl everyday',
#  'love song make wan na danc',
#  'time 2011 shirt cool',
#  'love video song cours',
#  'check video youtub',
#  'nice br yeah fuck',
#  'well dude fade fuck',
#  'ah good old time',
#  'old good song',
#  'cool',
#  '2 million view anymor',
#  'good',
#  'check video youtub',
#  'check video youtub br',
#  'remeb good ol 39 day song 39 butt',
#  'music hero',
#  'born wrong gener',
#  'love song make wan na danc',
#  'love song make wan na danc',
#  'good like',
#  'view 39 90 000',
#  'love lmfao parti rockin keep go',
#  'best music ever',
#  'likeee',
#  'cool',
#  'remeb song good',
#  '2015 lt 3',
#  'want robot guy',
#  'love song',
#  'omg 39 go 1bi view',
#  'danc',
#  'check video youtub',
#  '5 year',
#  'cool cool cool cool cool cool cool',
#  'wow love',
#  'know name girl one one',
#  'stop career music music rock',
#  'nice',
#  'sooooo mani down',
#  'tension',
#  'nice',
#  '2015 br like video',
#  'music yeah',
#  'like 2015',
#  'epic track video awesom',
#  'likke',
#  'give like',
#  'let parti',
#  'support fight 4th amend right privaci home busi stop nsa spi american un patriot act renew rand paul spent 10 5 hour senat floor protest filibust fight constitut nation found join fight rand paul dot com spread word someon care nation email senat congress men women tell support rand tell news support rand senat rand paul href http www youtub com watch v kq6zr6kcpj8 amp 1m00 1 00 morn fight constitut',
#  'mindblow danc superbbb song',
#  'anyon els think video theme bit insult 28 day later',
#  'check video youtub',
#  'never get old',
#  'rememb use popular around time br still love',
#  'strong messag everi song 39 heard',
#  '4 fuck year fuck past fuck fast fuck',
#  'know old song like watch 2015',
#  '39 watch summer 2015',
#  'go blow mind',
#  'shufflin still today',
#  'favorit song ever love parti rock everybodi',
#  '1000000000 view',
#  'let get 1 billion',
#  'love soooooooooooooooooooooooooooooooooooooooooooooooooo much',
#  'love song much',
#  '39 subscrib',
#  'song awesom',
#  'best song ever made swear still hear even doe old els',
#  'came vanoss',
#  'best song ever br',
#  'epic',
#  'like much music good',
#  'beauti song',
#  'feel like gangnam style copi song',
#  'damn everywher',
#  'parti time',
#  'never get old',
#  'song fu cking awesom',
#  'put pictur imag thingi',
#  'okay cover time thumb 39 watch youtub still exist',
#  'song insan br danc listen song lol',
#  '',
#  'thumb shrek gay',
#  'thumb robo guy babi',
#  'serious come beat insan good holi fuck',
#  'best parti song liter parti rock house tonight',
#  'memori',
#  'love',
#  'view nikki minaj anaconda',
#  'lmfao best',
#  'els saw jess danc sorri spell wrong peac',
#  'like robot shuffl shuffl good',
#  'cant stop shuffl',
#  'dang dat littl kid gat move',
#  'miss song',
#  'love',
#  'check video youtub br got ta danc blast everi time hear song love br',
#  'man song realli get bone one minut 39 nearli dose sleep next 39 shuffl like crazi hot feet xd',
#  'shake golden black robot realli parti',
#  'take look video youtub',
#  'cooooooooooooolllllllllll',
#  'wow',
#  'oh shit upload birthday final birthday isnt curs day maylaysia airlin went miss thought birthday curs xd',
#  'everyday 39 shufflin',
#  'everyday 39 shufflin',
#  'thumb fe fe fe fe fegelein brought u',
#  'everi day 39 shuffl',
#  'cool song ever good thing',
#  'world shuffl',
#  'love guy love song',
#  'funni listen rock death metal like',
#  'shuffl way lmfao like one wish could shuffl like crazi dude',
#  '5th view video guess',
#  'favorit song',
#  'like song br',
#  'wow danc show',
#  'awesom',
#  'like ur watchin  1',
#  'good time',
#  'laugh fuck ass',
#  'see back 2015 ask peopl got like song seem like gangnam style copi style though might yea',
#  'wait saw kid kid',
#  'parti rock due duel',
#  'fuck love omg v',
#  'good danc companion front whole school',
#  'check video youtub',
#  'could final spongebob start yesterday xd',
#  'thumb 39 watch 2015',
#  'love',
#  'lmfao parti rock anthem ft lauren bennett goonrock',
#  'hate laura bennett come',
#  'subscrib channel',
#  'parti da tonight',
#  'best parti',
#  'omg',
#  '39 guy jacket 1 sleev sleeveless arm',
#  'best song ever',
#  'take look video youtub br',
#  'like step',
#  'let get video one billion view',
#  'head like 2 year ago time fli',
#  '870 000 000 view 566 000 comment oh lanta',
#  '2015 still shuffl song',
#  'check video youtub',
#  'df lauren bennett',
#  'cool',
#  'awesom',
#  'cool 39 heard',
#  'xd go crazi fuckin crazi watchin brah',
#  'shuffl listen song ill spread',
#  'way guy war robot head',
#  'like song',
#  'almost 1 billion view nice',
#  'sorri hater br br br br br br br br br br br br br parti rock en',
#  'like br',
#  'gooooood',
#  '3',
#  'likeeeeeeee',
#  'shuffl',
#  'lol funni love',
#  'good parti',
#  'like comment watch 2004',
#  'check video youtub',
#  'check playlist youtub',
#  'check video youtub',
#  'share thought',
#  'subscrib plzzzzzzz plzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz',
#  'youtub collabor 39 anyon subscrib 39 subscrib back also start upload youtub video rel nofollow class ot hashtag href http plu googl com 23lmfao lmfao',
#  'guy lmfaoi go reunion june 27 15 expo idaho garden go 2 perform live 39 go 2 press confer answer question live channel got publish right subscrib channel watch whole thing u 39 believ look hope see u true fan ye 39 free',
#  'iiiiiiiiiii love shake song oh sorri everi shake song like watch subscrib never unlik brooooo shake',
#  'check playlist youtub',
#  'check video youtub br br br br',
#  'check video youtub',
#  '39 watch 2015 subscrib',
#  'come subscrib',
#  'subscrib channel pleas lol pro play',
#  'check video youtub',
#  'check video youtub',
#  'wan na see mani peopl like comment 39 give month',
#  'pleas 39 like comment watch 2015',
#  'check video youtub',
#  'like comment kill p',
#  'check video youtub',
#  'check playlist youtub',
#  'check video youtub',
#  'check video youtub',
#  'check video youtub',
#  'check video youtub fb',
#  'school drop out knew friend decid drop school think need id card certif prove educ clean crimin record talent person work entertain field worldwid think could rich entertain consolid actor actress well singer share profit',
#  'check video youtub',
#  'check video youtub',
#  'check video youtub',
#  'check playlist youtub br br br br',
#  'check video youtub',
#  'check playlist youtub br br',
#  'check video youtub',
#  'check video youtub',
#  'check video youtub',
#  'view 851 247 920 br br best youtub video br subscrib channel pleas br thank lt 3 br br melhor v deo youtub br se inscreva meu canal por favor br obrigado lt 3 br br mejor video youtub br si suscriba mi canal por favor br gracia lt 3 br br meilleur vid youtub br si vou abonn cha ne se il vou pla br merci lt 3',
#  'parti next share',
#  'lol check chanel subscrib pleas want 5000 sub that im nearli',
#  'check video youtub',
#  'check video youtub',
#  'subscrib leav name sub back',
#  'check video youtub',
#  'pleas subscrib channel thank',
#  'hey guy im 17 year old remix produc want guy help check video sure love music love subscrib know',
#  'check melbourn shuffl everybodi',
#  'subscrib channel',
#  'pleas suscrib bore 5 subscrib tri get 20',
#  'subscrib watch 2015',
#  'check video youtub br',
#  'hey subscrib peac world',
#  'check playlist youtub',
#  'check video youtub',
#  'check playlist youtub',
#  'like comment reason',
#  'omg first video youtub hit 1 billion view like comment agre',
#  'br pleas help get 100 subscrib end night thx',
#  'like comment 39 watch video big bang happen br',
#  'check playlist youtub br br',
#  'check playlist youtub',
#  'br br br br br br spook spookinati br br share 666 peopl unspook br br br br br br br br',
#  'like comment watch 2015 2016',
#  'help get 10000000 subscrib tomorrow br br br br br br br br br br br joke 39 get butt hurt',
#  'check video youtub',
#  'like comment ur watch 2015',
#  'check video youtub',
#  'like comment pleas',
#  'check playlist youtub',
#  'like subscrib',
#  'like comment watch phone',
#  'cool video lmfaovevo check shuffl video channel get chanc 39 much appreci cheer rel nofollow class ot hashtag href http plu googl com 23everydayimvap everydayimvap',
#  'check playlist youtub',
#  'check playlist youtub tri',
#  'subscrib span class proflinkwrapp span class proflinkprefix span class proflink href http plu googl com 104999962146104962510 oid 104999962146104962510 supermariologan span thot robot dude r epic awsom',
#  'watch 2015 subscrib span class proflinkwrapp span class proflinkprefix span class proflink href http plu googl com 104999962146104962510 oid 104999962146104962510 supermariologan span',
#  'check playlist youtub',
#  'like comment still jam song 4 year',
#  'subscrib',
#  'check video youtub',
#  'video 800 view br channel got 3m subscrib',
#  'check video youtub',
#  'subscrib chanel',
#  'lo invito subscribirs mi canal',
#  'check video youtub',
#  'check playlist youtub',
#  'check video youtub oppon mm br br br br br',
#  'check video youtub br br',
#  '500 subscrib 39 sky dive help reach goal lt 3 br trust 39 doctor',
#  'check video youtub',
#  'check video youtub',
#  'check video youtub',
#  'check playlist youtub',
#  'check playlist youtub',
#  'check video youtub',
#  ...]

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
X = cv.fit_transform(corpus).toarray() #bag of the words

y = df.iloc[:, 1].values

# %% [markdown]
# ----

# %% [markdown]
# ## Create the train & test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2, random_state = 0)

# %%
for df in [X_train, X_test, y_train, y_test]:
    print(df.shape)
# Out:
# (1564, 3772)
# (392, 3772)
# (1564,)
# (392,)

# %% [markdown]
# -----

# %% [markdown]
# ## Train different models (Binary Classifier)

# %% [markdown]
# - Model evaluation Metric: AUC ROC Curve & accuracy Score

# %% [markdown]
# ### 0. Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB #because there is a lot of 0 ,1 
clf_nb = MultinomialNB()
clf_nb.fit(X_train,y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
y_pred_nb = clf_nb.predict(X_test)
y_proba_nb = clf_nb.predict_proba(X_test)

# %%
from sklearn.metrics import confusion_matrix , accuracy_score , roc_auc_score

y_scores_nb = y_proba_nb[:, 1]
auc_nb = roc_auc_score (y_test, y_scores_nb)
print("The AUC score for Naive Bayes is: ", auc_nb)


acc_nb = accuracy_score(y_test, y_pred_nb)
print("The Accuracy score for Naive Bayes is: ", acc_nb)

cm_nb = confusion_matrix(y_test, y_pred_nb)
print("The Confusion matrix for Naive Bayes is: \n" , cm_nb)
# Out:
# The AUC score for Naive Bayes is:  0.952179255889
# The Accuracy score for Naive Bayes is:  0.915816326531
# The Confusion matrix for Naive Bayes is:
#  [[166  17]
#  [ 16 193]]

# %% [markdown]
# ### 1. Logistic Regression

# %%
# Fitting Logistic Regression to the Training set
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

param_grid = [{'penalty': ['l2','l1']}]

grid_search = GridSearchCV(LogisticRegression(), param_grid, cv= 4,
                       scoring='roc_auc', n_jobs = -1)
grid_search.fit(X_train,y_train)
print ("best parameter: ", grid_search.best_params_)

best_model_log = grid_search.best_estimator_
print ("best_model: ", best_model_log)
# Out:
# best parameter:  {'penalty': 'l2'}
# best_model:  LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
# Predicting the Test set results
y_pred_log = best_model_log.predict(X_test)
y_proba_log = best_model_log.predict_proba(X_test)

# %%
# Evaluate the Model
from sklearn.metrics import roc_auc_score , accuracy_score, confusion_matrix

y_scores_log = y_proba_log[:, 1]
auc_log = roc_auc_score (y_test, y_scores_log)
print("The AUC score for Logistic Regression is: ", auc_log)

acc_log = accuracy_score(y_test, y_pred_log)
print("The Accuracy score for Logistic Regression is: ", acc_log)

cm_log = confusion_matrix(y_test, y_pred_log)
print("The Confusion matrix for Logistic Regression is: \n" , cm_log)
# Out:
# The AUC score for Logistic Regression is:  0.98227311946
# The Accuracy score for Logistic Regression is:  0.933673469388
# The Confusion matrix for Logistic Regression is:
#  [[175   8]
#  [ 18 191]]

# %% [markdown]
# ### 2. K- Nearnest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

param_grid = [{'n_neighbors': [5, 10, 50, 100]}]

grid_search = GridSearchCV(KNeighborsClassifier(), param_grid, cv= 4,
                       scoring='roc_auc', n_jobs = -1)
grid_search.fit(X_train,y_train)
print ("best parameter: ", grid_search.best_params_)

best_model_knn = grid_search.best_estimator_
print ("best_model: ", best_model_knn)
# Out:
# best parameter:  {'n_neighbors': 10}
# best_model:  KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=10, p=2,
#            weights='uniform')

# %%
# Predicting the Test set results
y_pred_knn = best_model_knn.predict(X_test)
y_proba_knn = best_model_knn.predict_proba(X_test)

# %%
# Evaluate the Model
y_scores_knn = y_proba_knn[:, 1]
auc_knn = roc_auc_score (y_test, y_scores_knn)
print("The AUC score for KNN is: ", auc_knn)

acc_knn = accuracy_score(y_test, y_pred_knn)
print("The Accuracy score for KNN is: ", acc_knn)

cm_knn = confusion_matrix(y_test, y_pred_knn)
print("The Confusion matrix for KNN is: \n" , cm_knn)
# Out:
# The AUC score for KNN is:  0.948113577535
# The Accuracy score for KNN is:  0.821428571429
# The Confusion matrix for KNN is:
#  [[178   5]
#  [ 65 144]]

# %% [markdown]
# ### 3. SVM

# %%
from sklearn.svm import SVC
param_grid = [{
        'kernel': ['linear', 'rbf'] ,
            'C': [ 0.1, 1, 10, 20]
            }]


grid_search_svm = GridSearchCV(SVC(random_state=42), param_grid, cv= 4,
                                scoring='accuracy', n_jobs = -1)

grid_search_svm.fit(X_train,y_train)
print ("best parameter: ", grid_search_svm.best_params_)

best_model_svm = grid_search_svm.best_estimator_
print ("best_model: ", best_model_svm)
# Out:
# best parameter:  {'C': 1, 'kernel': 'linear'}
# best_model:  SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=42, shrinking=True,
#   tol=0.001, verbose=False)

# %%
# Predicting the Test set results
y_pred_svm = best_model_svm.predict(X_test_sc)

# Evaluate the Model
acc_svm = accuracy_score(y_test, y_pred_svm)
print("The Accuracy score for SVM is: ", acc_svm)

cm_svm = confusion_matrix(y_test, y_pred_svm)
print("The Confusion matrix for SVM is: \n" , cm_svm)
# Out:
# The Accuracy score for SVM is:  0.885204081633
# The Confusion matrix for SVM is:
#  [[168  15]
#  [ 30 179]]

# %% [markdown]
# ### 4. Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

param_grid = [{'n_estimators': [50, 100, 200 , 300],
              'max_depth': [3, 7, 10 , 14] }]

grid_search_rf = GridSearchCV(RandomForestClassifier(random_state=42), 
                              param_grid, cv= 3,
                                scoring='roc_auc', n_jobs = -1)

grid_search_rf.fit(X_train,y_train)
print ("best parameter: ", grid_search_rf.best_params_)

best_model_rf = grid_search_rf.best_estimator_
print ("best_model: ", best_model_rf)
# Out:
# best parameter:  {'n_estimators': 300, 'max_depth': 14}
# best_model:  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=14, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=300, n_jobs=1, oob_score=False, random_state=42,
#             verbose=0, warm_start=False)

# %%
# Predicting the Test set results
y_pred_rf = best_model_rf.predict(X_test)
y_proba_rf = best_model_rf.predict_proba(X_test)

# %%
# Evaluate the Model
y_scores_rf = y_proba_rf[:, 1]
auc_rf = roc_auc_score (y_test, y_scores_rf)
print("The AUC score for RandomForests is: ", auc_rf)

acc_rf = accuracy_score(y_test, y_pred_rf)
print("The Accuracy score for RandomForests is: ", acc_rf)

cm_rf = confusion_matrix(y_test, y_pred_rf)
print("The Confusion matrix for RandomForests is: \n" , cm_rf)
# Out:
# The AUC score for RandomForests is:  0.978364316156
# The Accuracy score for RandomForests is:  0.915816326531
# The Confusion matrix for RandomForests is:
#  [[181   2]
#  [ 31 178]]

# %% [markdown]
# ### ROC Curves & Compare models

# %%
from sklearn.metrics import roc_curve
def plot_roc_curve(fpr, tpr, label=None):
    plt.plot(fpr, tpr, linewidth=2, label=label)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.axis([0, 1, 0, 1])
    plt.xlabel('False Positive Rate', fontsize=16)
    plt.ylabel('True Positive Rate', fontsize=16)

# %%
fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_test,y_scores_rf)
fpr_knn, tpr_knn, thresholds_knn = roc_curve(y_test,y_scores_knn)
fpr_log, tpr_log, thresholds_log = roc_curve(y_test,y_scores_log)
fpr_nb, tpr_nb, thresholds_nb = roc_curve(y_test,y_scores_nb)

# %%
plt.figure(figsize=(8, 6))
plt.plot(fpr_rf, tpr_rf, "g--", linewidth=2, label="RandomForests")
plt.plot(fpr_nb, tpr_nb, "b:", linewidth=2, label="Naive Bayes")
plt.plot(fpr_knn, tpr_knn, "r-.", linewidth=2, label="KNN")
plot_roc_curve(fpr_log, tpr_log, "LogisticRegression")
plt.legend(loc="lower right", fontsize=16)
plt.show()

# %% [markdown]
# ### Compare Accuracy Rates

# %%
acc_scores = {"Model": ["Navie Bayes","Logistic Regression", "KNN", "SVM", "RandomForests"],
             "Accuracy Score": [acc_nb, acc_log , acc_knn, acc_svm, acc_rf]}

acc_df = pd.DataFrame(acc_scores)
acc_df = acc_df [["Model", "Accuracy Score"]]
acc_df
# Out:
#                  Model  Accuracy Score
# 0          Navie Bayes        0.915816
# 1  Logistic Regression        0.933673
# 2                  KNN        0.821429
# 3                  SVM        0.931122
# 4        RandomForests        0.915816

# %% [markdown]
# ### Visalization

# %%
spam = df.loc[df.CLASS == 1]
ham = df.loc[df.CLASS ==0]

# %%
spam.head()
# Out:
#                                     COMMENT_ID            AUTHOR  \
# 0  LZQPQhLyRh80UYxNuaDWhIGQYNQ96IuCg-AYWqNPjpU         Julius NM
# 1  LZQPQhLyRh_C2cTtd9MvFRJedxydaVW-2sNg5Diuo4A       adam riyati
# 2  LZQPQhLyRh9MSZYnf8djyk0gEF9BHDPYrrK-qCczIY8  Evgeny Murashkin
# 3          z13jhp0bxqncu512g22wvzkasxmvvzjaz04   ElNino Melendez
# 4          z13fwbwp1oujthgqj04chlngpvzmtt3r3dw            GsMega
#
#                   DATE                                            CONTENT  \
# 0  2013-11-07T06:20:48  Huh, anyway check out this you[tube] channel: ...
# 1  2013-11-07T12:37:15  Hey guys check out my new channel and our firs...
# 2  2013-11-08T17:34:21             just for test I have to say murdev.com
# 3  2013-11-09T08:28:43   me shaking my sexy ass on my channel enjoy ^_^ ﻿
# 4  2013-11-10T16:05:38            watch?v=vtaRGgvGtWQ   Check this out .﻿
#
#    CLASS
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
# it is better to do it after removing stop words

words_spam = ''
for i in range(len(spam)):
    words_spam = words_spam + spam.iloc[i , 3] + ' ' 

words_ham = ''
for i in range(len(ham)):
    words_ham = words_ham + ham.iloc[i , 3] + ' '

# %%
from wordcloud import WordCloud
# Generate a word cloud image
spam_wordcloud = WordCloud(width=400, height=200).generate(words_spam)
ham_wordcloud = WordCloud(width=400, height=200).generate(words_ham)

# %%
#Spam Word cloud
plt.figure( figsize=(10,8), facecolor='k')
plt.imshow(spam_wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
#Ham word cloud
plt.figure( figsize=(10,8), facecolor='k')
plt.imshow(ham_wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
